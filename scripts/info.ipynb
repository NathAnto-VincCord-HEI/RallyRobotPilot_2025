# %% [markdown]
# fitness = (
#
#     distance_parcourue * 2.0 +           # Distance importante
#
#     checkpoints_passés * 100.0 +         # Checkpoints TRÈS importants
#
#     vitesse_max * 0.5 +                  # Vitesse modérée
#
#     frames_survécus * 0.1 -              # Bonus survie
#
#     nb_collisions * 5.0                  # Pénalité collisions
#
# )
#
#
# # Bonus spécial si tour complet
#
# if tous_checkpoints_passés:
#
#     fitness += 500

# %% [markdown]
# python train_teacher_model.py \
#
#     --population 50 \
#
#     --generations 50 \
#
#     --simulation-time 80
